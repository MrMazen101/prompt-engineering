# %%
import google.generativeai as genai
from dotenv import dotenv_values

# 1. قراءة الـ API Key
env_values = dotenv_values("./app.env")
google_api_key = env_values['GOOGLE_API_KEY']

# 2. إعداد المفتاح
genai.configure(api_key=google_api_key)

# 3. استدعاء الموديل الصح من اللستة بتاعتك
model = genai.GenerativeModel('gemini-2.5-flash')

# 4. التجربة
prompt = "Suggest 2 ways to lose my weight."
response = model.generate_content(prompt)

print(response.text)
# Out:
# Here are two fundamental ways to lose weight:
#
# 1.  **Focus on a Calorie Deficit through Dietary Changes:**
#     *   **How it works:** To lose weight, you need to consume fewer calories than your body burns. Your body will then start to use its fat stores for energy.
#     *   **Actionable steps:**
#         *   **Prioritize whole foods:** Eat plenty of fruits, vegetables, lean proteins (chicken, fish, beans, tofu), and whole grains (oats, brown rice). These are nutrient-dense and generally lower in calories than processed foods.
#         *   **Reduce processed foods and sugary drinks:** Cut down on items like soda, juice, sweets, fast food, and packaged snacks, as they often contain a lot of empty calories, added sugars, and unhealthy fats.
#         *   **Control portion sizes:** Be mindful of how much you're eating, even with healthy foods. Use smaller plates, measure ingredients, and listen to your body's hunger and fullness cues.
#         *   **Stay hydrated:** Drink plenty of water throughout the day. Sometimes thirst can be mistaken for hunger.
#
# 2.  **Increase Physical Activity and Movement:**
#     *   **How it works:** Moving more helps burn more calories and builds muscle, which in turn boosts your metabolism (the rate at which your body burns calories at rest).
#     *   **Actionable steps:**
#         *   **Incorporate cardiovascular exercise:** Aim for at least 150-300 minutes of moderate-intensity cardio (like brisk walking, jogging, cycling, swimming, dancing) per week. This helps burn a significant number of calories.
#         *   **Include strength training:** Lift weights or do bodyweight exercises (push-ups, squats, lunges) 2-3 times a week. Building muscle helps you burn more calories even when you're not exercising.
#         *   **Increase daily non-exercise activity (NEAT):** Look for opportunities to move more throughout your day. Take the stairs instead of the elevator, walk or cycle short distances instead of driving, stand more often, and take short walking breaks during work.
#
# **Important Note:** For sustainable and healthy weight loss, it's often most effective to combine both strategies. Always consult with a doctor or a registered dietitian before making significant changes to your diet or exercise routine, especially if you have underlying health conditions.
